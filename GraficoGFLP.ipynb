# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorV1ana/desafios/blob/main/GraficoGFLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Gráfico Prova 1 - Victor Viana

# %%
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(9,6))


# plot da distribuição
x= np.arange(-3,3,0.001)
ax.plot(x, norm.pdf(x))
ax.set_title("Intervalo de confiança desejado",fontsize=16)
ax.set_xlabel('sigma',fontsize=12)
ax.set_ylabel('pdf(x)')
ax.grid(False)

# area da curva
px=np.arange(-3,1.645,0.01)
ax.set_ylim(0,0.5)
ax.fill_between(px,norm.pdf(px),alpha=0.5, color='green')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

# plot da distribuição
x= np.arange(-3,3,0.001)
ax.plot(x, norm.pdf(x))
ax.set_title("Intervalo de confiança do Projeto",fontsize=16)
ax.set_xlabel('sigma',fontsize=12)
ax.set_ylabel('pdf(x)')
ax.grid(False)

# area da curva
pxp=np.arange(-3,1.29121523,0.01)
ax.set_ylim(0,0.5)
ax.fill_between(pxp,norm.pdf(pxp),alpha=0.5, color='red')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(9,6))

# plot da distribuição
x= np.arange(-3,3,0.001)
ax.plot(x, norm.pdf(x))
ax.set_title("Projeto vs IC desejado",fontsize=16)
ax.set_xlabel('sigma',fontsize=12)
ax.set_ylabel('pdf(x)')
ax.grid(False)



# area da curva desejada
px=np.arange(-3,1.645,0.01)
ax.set_ylim(0,0.5)
ax.fill_between(px,norm.pdf(px),alpha=0.5, color='g')

# area da curva projeto
pxp=np.arange(-3,1.29121523,0.01)
ax.set_ylim(0,0.5)
ax.fill_between(pxp,norm.pdf(pxp),alpha=0.5, color='red')


plt.show()
